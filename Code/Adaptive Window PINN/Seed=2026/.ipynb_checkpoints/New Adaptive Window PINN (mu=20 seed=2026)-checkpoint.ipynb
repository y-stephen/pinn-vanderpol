# %%
import time
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

SEED = 2026
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.set_default_dtype(torch.float64)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

MU = 20.0 # nonlinearity factor
#T_FINAL = 24.0 (No need for this anymore, t_final is defined later)
X0 = 1.0 # initial position x(0)
V0 = 0.0 # initial velocity x'(0)

PERIOD_MARGIN = 1.15
ROUGH_PERIOD_FACTOR = 1.614
N_PERIODS_SETTLE = 4

N_WINDOWS_TARGET = 10 # initial equidistribution target: actual count may grow via MAX_WINDOW_WIDTH splitting
LAYERS = (1, 32, 32, 32, 32, 1)
N_COLLOCATION_PER_WINDOW = 2000
COLLOCATION_SCALE_CAP = 3.0
ADAM_EPOCHS = 3000
ADAM_LR = 1e-3
GRAD_CLIP_NORM = 10.0
LBFGS_MAX_ITER = 2000
PRINT_EVERY = 500

# Adaptive collocation resampling
RESAMPLE_EVERY = 500
RESAMPLE_CANDIDATE_MULT = 5
RESAMPLE_UNIFORM_FLOOR = 0.2

# Non-uniform window placement
COARSE_N_POINTS = 4000
MIN_WINDOW_WIDTH = 0.15
MAX_WINDOW_WIDTH = 3.0
MONITOR_VELOCITY_WEIGHT = 0.4
MONITOR_ACCEL_WEIGHT = 0.6

# Convergence retry
LOSS_CONVERGENCE_THRESHOLD = 1e-4
MAX_RETRIES_PER_WINDOW = 2
# Out:
# Using device: cuda

# %%
# Finds period of van der pol using reference solution to define T_FINAL
def van_der_pol_rhs(t, y, mu=MU):
    x, v = y
    return [v, mu * (1 - x ** 2) * v - x]

def estimate_vdp_period(mu, x0=X0, v0=V0, rough_factor=ROUGH_PERIOD_FACTOR, n_settle=N_PERIODS_SETTLE):
    rough_T = rough_factor * mu
    t_span = n_settle * max(rough_T, 5.0)
    def event_peak(t, y):
        return y[1]
    event_peak.direction = -1

    sol = solve_ivp(
        lambda t, y: van_der_pol_rhs(t, y, mu=mu),
        [0.0, t_span], [x0, v0],
        events=event_peak, rtol=1e-10, atol=1e-12, max_step=0.05,
    )
    peak_times = sol.t_events[0]
    if len(peak_times) < 3:
        print(f"[period detection] not enough peaks found, falling back to rough estimate {rough_T:.3f}")
        return rough_T
    period = peak_times[-1] - peak_times[-2]
    return period

vdp_period = estimate_vdp_period(MU)
T_FINAL = float(PERIOD_MARGIN * vdp_period)
print(f"Detected VdP period at mu={MU}: {vdp_period:.4f}  ->  T_FINAL = {T_FINAL:.4f}")
# Out:
# Detected VdP period at mu=20.0: 34.6823  ->  T_FINAL = 39.8847

# %%
class BasePINN(nn.Module):
    # Shared architecture skeleton: encode_input() + trunk_forward()

    def __init__(self):
        super().__init__()

    def encode_input(self, t):
        raise NotImplementedError

    def trunk_forward(self, encoded):
        raise NotImplementedError

    def forward(self, t):
        return self.trunk_forward(self.encode_input(t))

    @staticmethod
    def init_linear(linear):
        nn.init.xavier_normal_(linear.weight)
        nn.init.zeros_(linear.bias)

# %%
class VanillaPINN(BasePINN):
    # Standard PINN architecture
    def __init__(self, t_start, window_size, layers=LAYERS):
        super().__init__()
        self.t_start = t_start
        self.window_size = window_size
        self.trunk = nn.ModuleList()
        for i in range(len(layers) - 1):
            linear = nn.Linear(layers[i], layers[i + 1])
            self.init_linear(linear)
            self.trunk.append(linear)
        self.activation = torch.tanh

    def encode_input(self, t):
        tau = t - self.t_start
        return (2.0 * tau / self.window_size) - 1.0

    def trunk_forward(self, encoded):
        out = encoded
        for layer in self.trunk[:-1]:
            out = self.activation(layer(out))
        return self.trunk[-1](out)

# %%
class WindowPINN(nn.Module):
    """
    Time-marching wrapper, wraps base architecture (VanillaPINN) and enforces this window's initial condition exactly:
    x(t) = x0_local + v0_local * tau + tau^2 * base_model(t)
    """
    def __init__(self, base_model, t_start, window_size, x0_local, v0_local):
        super().__init__()
        self.base_model = base_model
        self.t_start = t_start
        self.window_size = window_size
        self.x0_local = x0_local
        self.v0_local = v0_local

    def forward(self, t):
        tau = t - self.t_start
        n_raw = self.base_model(t)
        return self.x0_local + self.v0_local * tau + (tau ** 2) * n_raw

# %%
def physics_residual(model, t, mu=MU):
    x = model(t)
    x_t = torch.autograd.grad(x, t, grad_outputs=torch.ones_like(x), create_graph=True, retain_graph=True)[0]
    x_tt = torch.autograd.grad(x_t, t, grad_outputs=torch.ones_like(x_t), create_graph=True, retain_graph=True)[0]
    return x_tt - mu * (1.0 - x ** 2) * x_t + x

def compute_loss(model, t_f):
    # only the physics residual; IC is hard-enforced, no loss_ic term
    f_pred = physics_residual(model, t_f)
    return torch.mean(f_pred ** 2)

def sample_collocation_points(t_start, t_end, n):
    t_f = np.random.uniform(low=t_start, high=t_end, size=(n, 1))
    t_f = torch.tensor(t_f, dtype=torch.get_default_dtype(), device=device)
    t_f.requires_grad_(True)
    return t_f

def evaluate_state(model, t_value):
    # (x, x') of a trained window model at a single time becomes the hard IC handed to the next window
    t_tensor = torch.tensor([[t_value]], dtype=torch.get_default_dtype(), device=device, requires_grad=True)
    x = model(t_tensor)
    x_t = torch.autograd.grad(x, t_tensor, grad_outputs=torch.ones_like(x))[0]
    return x.item(), x_t.item()

# %%
def adaptive_collocation_points(model, t_start, t_end, n_points, n_candidates_mult=RESAMPLE_CANDIDATE_MULT, uniform_floor=RESAMPLE_UNIFORM_FLOOR):
    # Draw a large uniform candidate pool, score each candidate by the current model's physics-residual magnitude, then keep points preferentially where the residual is large
    n_candidates = max(n_points * n_candidates_mult, n_points)
    t_candidates_np = np.random.uniform(t_start, t_end, size=(n_candidates, 1))
    t_candidates = torch.tensor(t_candidates_np, dtype=torch.get_default_dtype(), device=device)
    t_candidates.requires_grad_(True)
    residual = physics_residual(model, t_candidates)
    scores = (residual.detach() ** 2).cpu().numpy().flatten()
    scores += 1e-12
    probs = scores / scores.sum()
    n_weighted = int(round(n_points * (1.0 - uniform_floor)))
    n_uniform = n_points - n_weighted
    weighted_idx = np.random.choice(n_candidates, size=n_weighted, replace=False, p=probs)
    t_weighted_np = t_candidates_np[weighted_idx]
    t_uniform_np = np.random.uniform(t_start, t_end, size=(n_uniform, 1))
    t_new_np = np.vstack([t_weighted_np, t_uniform_np])
    t_new = torch.tensor(t_new_np, dtype=torch.get_default_dtype(), device=device)
    t_new.requires_grad_(True)
    return t_new

def compute_nonuniform_window_edges(n_windows, t_final=T_FINAL, mu=MU, x0=X0, v0=V0, coarse_n_points=COARSE_N_POINTS, min_width=MIN_WINDOW_WIDTH, max_width=MAX_WINDOW_WIDTH):
    t_coarse = np.linspace(0.0, t_final, coarse_n_points)
    sol = solve_ivp(lambda t, y: van_der_pol_rhs(t, y, mu=mu), [0.0, t_final], [x0, v0], t_eval=t_coarse, method="RK45", rtol=1e-9, atol=1e-9)
    x_c, v_c = sol.y[0], sol.y[1]
    accel = mu * (1 - x_c ** 2) * v_c - x_c
    vel_norm = np.abs(v_c) / (np.abs(v_c).max() + 1e-12)
    acc_norm = np.abs(accel) / (np.abs(accel).max() + 1e-12)
    monitor = MONITOR_VELOCITY_WEIGHT * vel_norm + MONITOR_ACCEL_WEIGHT * acc_norm
    cumulative = np.concatenate([[0.0], np.cumsum(0.5 * (monitor[1:] + monitor[:-1]) * np.diff(t_coarse))])
    total_measure = cumulative[-1]
    targets = np.linspace(0.0, total_measure, n_windows + 1)
    edges = np.interp(targets, cumulative, t_coarse)
    edges[0], edges[-1] = 0.0, t_final
    for i in range(1, len(edges) - 1):
        if edges[i] - edges[i - 1] < min_width:
            edges[i] = edges[i - 1] + min_width
    edges = np.clip(edges, 0.0, t_final)
    edges[-1] = t_final
    for i in range(len(edges) - 2, 0, -1):
        if edges[i + 1] - edges[i] < min_width:
            edges[i] = edges[i + 1] - min_width
    edges = np.clip(edges, 0.0, t_final)
    edges[0], edges[-1] = 0.0, t_final
    edges = np.unique(edges)
    new_edges = [edges[0]]
    for i in range(len(edges) - 1):
        a, b = edges[i], edges[i + 1]
        width = b - a
        n_sub = max(int(np.ceil(width / max_width)), 1)
        sub_edges = np.linspace(a, b, n_sub + 1)[1:]
        new_edges.extend(sub_edges.tolist())
    edges = np.unique(np.array(new_edges))
    return edges, t_coarse, monitor

# %%
def run_adam_phase(model, t_start, t_end, n_points, adam_epochs, window_idx, tag="Adam"):
    t_f = sample_collocation_points(t_start, t_end, n_points)
    history = []
    optimizer = torch.optim.Adam(model.parameters(), lr=ADAM_LR)
    for epoch in range(adam_epochs):
        if epoch > 0 and epoch % RESAMPLE_EVERY == 0:
            t_f = adaptive_collocation_points(model, t_start, t_end, n_points)
        optimizer.zero_grad()
        loss = compute_loss(model, t_f)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), GRAD_CLIP_NORM)
        optimizer.step()
        history.append(loss.item())
        if epoch % PRINT_EVERY == 0:
            print(f"[window {window_idx}] [{tag}]  epoch {epoch:5d} | loss {loss.item():.3e}")
    return history, t_f

def run_lbfgs_phase(model, t_f, max_iter, window_idx, tag="L-BFGS"):
    history = []
    optimizer_lbfgs = torch.optim.LBFGS(model.parameters(), max_iter=max_iter, tolerance_grad=1e-9, tolerance_change=1e-12, history_size=50, line_search_fn="strong_wolfe")
    counter = {"n": 0}
    def closure():
        optimizer_lbfgs.zero_grad()
        loss = compute_loss(model, t_f)
        loss.backward()
        history.append(loss.item())
        counter["n"] += 1
        if counter["n"] % PRINT_EVERY == 0:
            print(f"[window {window_idx}] [{tag}] iter {counter['n']:5d} | loss {loss.item():.3e}")
        return loss
    optimizer_lbfgs.step(closure)
    return history

# %%
def train_window(model, t_start, t_end, n_points, adam_epochs, window_idx=0):
    history, t_f = run_adam_phase(model, t_start, t_end, n_points, adam_epochs, window_idx, tag="Adam")
    t_f = adaptive_collocation_points(model, t_start, t_end, n_points)
    history += run_lbfgs_phase(model, t_f, LBFGS_MAX_ITER, window_idx, tag="L-BFGS")

    # convergence check + automatic retries with fresh adaptive resampling
    retries = 0
    while history[-1] > LOSS_CONVERGENCE_THRESHOLD and retries < MAX_RETRIES_PER_WINDOW:
        retries += 1
        print(f"[window {window_idx}] loss {history[-1]:.3e} > {LOSS_CONVERGENCE_THRESHOLD:.1e} threshold "
              f"-> retry {retries}/{MAX_RETRIES_PER_WINDOW}")
        t_f = adaptive_collocation_points(model, t_start, t_end, n_points)
        history += run_lbfgs_phase(model, t_f, LBFGS_MAX_ITER, window_idx, tag=f"L-BFGS-retry{retries}")

    return history

# %%
window_edges, coarse_t, coarse_monitor = compute_nonuniform_window_edges(N_WINDOWS_TARGET)
window_widths = np.diff(window_edges)
n_windows_actual = len(window_widths)
mean_width = window_widths.mean()
print(f"Non-uniform window edges (t): {np.round(window_edges, 3)}")
print(f"Window widths: {np.round(window_widths, 3)}")
print(f"Actual window count after MAX_WIDTH splitting: {n_windows_actual} (target was {N_WINDOWS_TARGET})")

start_time = time.time()

models = []
full_history = []
x0_cur, v0_cur = X0, V0
prev_base_state = None
for w in range(n_windows_actual):
    t_start = float(window_edges[w])
    t_end = float(window_edges[w + 1])
    width = t_end - t_start
    # scale collocation points and Adam epochs by window width relative to the mean
    width_ratio = width / mean_width
    n_points_w = int(round(N_COLLOCATION_PER_WINDOW * np.clip(width_ratio, 1.0, COLLOCATION_SCALE_CAP)))
    adam_epochs_w = int(round(ADAM_EPOCHS * np.clip(width_ratio, 1.0, 2.0)))
    base = VanillaPINN(t_start, width).to(device)
    if prev_base_state is not None:
        base.load_state_dict(prev_base_state)  # warm start from previous window (same architecture)

    model_w = WindowPINN(base, t_start, width, x0_cur, v0_cur).to(device)
    hist = train_window(model_w, t_start, t_end, n_points_w, adam_epochs_w, window_idx=w)
    full_history.extend(hist)
    x0_cur, v0_cur = evaluate_state(model_w, t_end)
    models.append(model_w)
    prev_base_state = base.state_dict()

training_time = time.time() - start_time
print(f"Time-marching training complete in {training_time:.1f}s.")
# Out:
# Non-uniform window edges (t): [ 0.     0.723  0.873  1.023  3.845  6.668  9.49  12.312 15.134 17.957
#  18.107 18.257 21.062 23.867 26.671 29.476 32.281 35.086 35.341 35.491
#  37.688 39.885]
# Window widths: [0.723 0.15  0.15  2.822 2.822 2.822 2.822 2.822 2.822 0.15  0.15  2.805
#  2.805 2.805 2.805 2.805 2.805 0.255 0.15  2.197 2.197]
# Actual window count after MAX_WIDTH splitting: 21 (target was 10)
# [window 0] [Adam]  epoch     0 | loss 9.407e+00
# [window 0] [Adam]  epoch   500 | loss 4.435e-01
# [window 0] [Adam]  epoch  1000 | loss 3.847e-01
# [window 0] [Adam]  epoch  1500 | loss 4.873e-01
# [window 0] [Adam]  epoch  2000 | loss 2.533e-01
# [window 0] [Adam]  epoch  2500 | loss 5.060e-01
# [window 0] [L-BFGS] iter   500 | loss 2.510e-05
# [window 0] [L-BFGS] iter  1000 | loss 1.070e-05
# [window 0] [L-BFGS] iter  1500 | loss 1.340e-06
# [window 0] [L-BFGS] iter  2000 | loss 5.084e-08
# [window 1] [Adam]  epoch     0 | loss 7.705e+05
# [window 1] [Adam]  epoch   500 | loss 3.921e+04
# [window 1] [Adam]  epoch  1000 | loss 4.099e+04
# [window 1] [Adam]  epoch  1500 | loss 3.034e+04
# [window 1] [Adam]  epoch  2000 | loss 2.135e+04
# [window 1] [Adam]  epoch  2500 | loss 1.511e+04
# [window 1] [L-BFGS] iter   500 | loss 5.666e-01
# [window 1] [L-BFGS] iter  1000 | loss 2.807e-02
# [window 1] [L-BFGS] iter  1500 | loss 8.721e-03
# [window 1] [L-BFGS] iter  2000 | loss 5.285e-03
# [window 1] loss 2.042e-03 > 1.0e-04 threshold -> retry 1/2
# [window 1] [L-BFGS-retry1] iter   500 | loss 1.087e-03
# [window 1] [L-BFGS-retry1] iter  1000 | loss 5.015e-04
# [window 1] [L-BFGS-retry1] iter  1500 | loss 2.577e-04
# [window 1] [L-BFGS-retry1] iter  2000 | loss 2.455e-04
# [window 1] loss 2.382e-04 > 1.0e-04 threshold -> retry 2/2
# [window 1] [L-BFGS-retry2] iter   500 | loss 2.464e-04
# [window 1] [L-BFGS-retry2] iter  1000 | loss 1.601e-04
# [window 1] [L-BFGS-retry2] iter  1500 | loss 1.126e-04
# [window 1] [L-BFGS-retry2] iter  2000 | loss 1.004e-04
# [window 2] [Adam]  epoch     0 | loss 6.826e+05
# [window 2] [Adam]  epoch   500 | loss 1.885e+01
# [window 2] [Adam]  epoch  1000 | loss 1.416e+00
# [window 2] [Adam]  epoch  1500 | loss 9.977e-02
# [window 2] [Adam]  epoch  2000 | loss 1.669e-02
# [window 2] [Adam]  epoch  2500 | loss 8.218e-01
# [window 3] [Adam]  epoch     0 | loss 1.155e+06
# [window 3] [Adam]  epoch   500 | loss 2.477e+01
# [window 3] [Adam]  epoch  1000 | loss 5.555e+00
# [window 3] [Adam]  epoch  1500 | loss 3.378e+01
# [window 3] [Adam]  epoch  2000 | loss 3.696e+00
# [window 3] [Adam]  epoch  2500 | loss 8.756e-01
# [window 3] [Adam]  epoch  3000 | loss 2.703e+00
# [window 3] [Adam]  epoch  3500 | loss 7.355e+00
# [window 3] [Adam]  epoch  4000 | loss 2.872e+00
# [window 4] [Adam]  epoch     0 | loss 4.166e-04
# [window 4] [Adam]  epoch   500 | loss 1.001e-02
# [window 4] [Adam]  epoch  1000 | loss 3.941e+00
# [window 4] [Adam]  epoch  1500 | loss 8.464e+00
# [window 4] [Adam]  epoch  2000 | loss 1.077e+01
# [window 4] [Adam]  epoch  2500 | loss 2.898e-01
# [window 4] [Adam]  epoch  3000 | loss 5.472e+00
# [window 4] [Adam]  epoch  3500 | loss 2.428e+00
# [window 4] [Adam]  epoch  4000 | loss 1.828e+01
# [window 5] [Adam]  epoch     0 | loss 2.032e-03
# [window 5] [Adam]  epoch   500 | loss 1.369e-01
# [window 5] [Adam]  epoch  1000 | loss 7.293e-02
# [window 5] [Adam]  epoch  1500 | loss 2.935e-02
# [window 5] [Adam]  epoch  2000 | loss 2.093e-02
# [window 5] [Adam]  epoch  2500 | loss 2.900e-02
# [window 5] [Adam]  epoch  3000 | loss 7.387e-02
# [window 5] [Adam]  epoch  3500 | loss 1.963e-01
# [window 5] [Adam]  epoch  4000 | loss 4.817e-01
# [window 6] [Adam]  epoch     0 | loss 3.890e-03
# [window 6] [Adam]  epoch   500 | loss 4.238e-03
# [window 6] [Adam]  epoch  1000 | loss 3.084e+00
# [window 6] [Adam]  epoch  1500 | loss 6.206e-01
# [window 6] [Adam]  epoch  2000 | loss 6.332e-02
# [window 6] [Adam]  epoch  2500 | loss 4.962e-01
# [window 6] [Adam]  epoch  3000 | loss 5.795e-02
# [window 6] [Adam]  epoch  3500 | loss 1.146e-02
# [window 6] [Adam]  epoch  4000 | loss 6.430e-02
# [window 6] [L-BFGS] iter   500 | loss 7.151e-06
# [window 6] [L-BFGS] iter  1000 | loss 7.572e-07
# [window 6] [L-BFGS] iter  1500 | loss 1.282e-07
# [window 6] [L-BFGS] iter  2000 | loss 1.264e-07
# [window 7] [Adam]  epoch     0 | loss 1.548e-02
# [window 7] [Adam]  epoch   500 | loss 1.504e-03
# [window 7] [Adam]  epoch  1000 | loss 1.174e-03
# [window 7] [Adam]  epoch  1500 | loss 3.234e-04
# [window 7] [Adam]  epoch  2000 | loss 5.131e-04
# [window 7] [Adam]  epoch  2500 | loss 8.169e-04
# [window 7] [Adam]  epoch  3000 | loss 2.875e-04
# [window 7] [Adam]  epoch  3500 | loss 9.789e-04
# [window 7] [Adam]  epoch  4000 | loss 3.734e-04
# [window 8] [Adam]  epoch     0 | loss 1.497e-01
# [window 8] [Adam]  epoch   500 | loss 2.816e-02
# [window 8] [Adam]  epoch  1000 | loss 5.072e-01
# [window 8] [Adam]  epoch  1500 | loss 1.329e-01
# [window 8] [Adam]  epoch  2000 | loss 5.136e-02
# [window 8] [Adam]  epoch  2500 | loss 1.247e-01
# [window 8] [Adam]  epoch  3000 | loss 5.316e-02
# [window 8] [Adam]  epoch  3500 | loss 3.298e-02
# [window 8] [Adam]  epoch  4000 | loss 7.164e-01
# [window 8] [L-BFGS] iter   500 | loss 1.987e-05
# [window 8] [L-BFGS] iter  1000 | loss 1.694e-06
# [window 8] [L-BFGS] iter  1500 | loss 1.183e-06
# [window 8] [L-BFGS] iter  2000 | loss 1.182e-06
# [window 8] [L-BFGS] iter  2500 | loss 1.181e-06
# [window 9] [Adam]  epoch     0 | loss 1.729e+04
# [window 9] [Adam]  epoch   500 | loss 1.006e+02
# [window 9] [Adam]  epoch  1000 | loss 1.552e+02
# [window 9] [Adam]  epoch  1500 | loss 2.739e+02
# [window 9] [Adam]  epoch  2000 | loss 1.963e+02
# [window 9] [Adam]  epoch  2500 | loss 2.189e+01
# [window 9] [L-BFGS] iter   500 | loss 3.857e-03
# [window 9] [L-BFGS] iter  1000 | loss 1.915e-04
# [window 9] [L-BFGS] iter  1500 | loss 7.874e-05
# [window 9] [L-BFGS] iter  2000 | loss 1.998e-05
# [window 10] [Adam]  epoch     0 | loss 2.439e+06
# [window 10] [Adam]  epoch   500 | loss 1.685e+00
# [window 10] [Adam]  epoch  1000 | loss 2.680e+00
# [window 10] [Adam]  epoch  1500 | loss 4.023e+00
# [window 10] [Adam]  epoch  2000 | loss 4.368e+00
# [window 10] [Adam]  epoch  2500 | loss 1.879e-01
# [window 10] [L-BFGS] iter   500 | loss 2.604e-06
# [window 10] [L-BFGS] iter  1000 | loss 2.058e-06
# [window 10] [L-BFGS] iter  1500 | loss 2.055e-06
# [window 10] [L-BFGS] iter  2000 | loss 2.053e-06
# [window 10] [L-BFGS] iter  2500 | loss 2.050e-06
# [window 11] [Adam]  epoch     0 | loss 1.353e+12
# [window 11] [Adam]  epoch   500 | loss 5.222e+01
# [window 11] [Adam]  epoch  1000 | loss 4.443e+01
# [window 11] [Adam]  epoch  1500 | loss 1.367e+02
# [window 11] [Adam]  epoch  2000 | loss 1.942e+02
# [window 11] [Adam]  epoch  2500 | loss 2.608e+02
# [window 11] [Adam]  epoch  3000 | loss 1.904e+02
# [window 11] [Adam]  epoch  3500 | loss 4.708e+01
# [window 11] [Adam]  epoch  4000 | loss 3.389e+00
# [window 12] [Adam]  epoch     0 | loss 3.149e-04
# [window 12] [Adam]  epoch   500 | loss 3.129e+00
# [window 12] [Adam]  epoch  1000 | loss 2.531e-01
# [window 12] [Adam]  epoch  1500 | loss 8.793e+00
# [window 12] [Adam]  epoch  2000 | loss 1.464e+01
# [window 12] [Adam]  epoch  2500 | loss 3.828e+00
# [window 12] [Adam]  epoch  3000 | loss 1.455e+01
# [window 12] [Adam]  epoch  3500 | loss 9.422e-02
# [window 12] [Adam]  epoch  4000 | loss 1.833e+00
# [window 13] [Adam]  epoch     0 | loss 1.985e-03
# [window 13] [Adam]  epoch   500 | loss 1.806e+00
# [window 13] [Adam]  epoch  1000 | loss 3.264e+00
# [window 13] [Adam]  epoch  1500 | loss 6.708e-03
# [window 13] [Adam]  epoch  2000 | loss 1.012e+00
# [window 13] [Adam]  epoch  2500 | loss 5.947e-01
# [window 13] [Adam]  epoch  3000 | loss 8.308e-01
# [window 13] [Adam]  epoch  3500 | loss 2.516e-01
# [window 13] [Adam]  epoch  4000 | loss 7.791e-01
# [window 14] [Adam]  epoch     0 | loss 3.876e-03
# [window 14] [Adam]  epoch   500 | loss 1.462e-02
# [window 14] [Adam]  epoch  1000 | loss 2.304e-02
# [window 14] [Adam]  epoch  1500 | loss 7.995e-01
# [window 14] [Adam]  epoch  2000 | loss 1.896e-02
# [window 14] [Adam]  epoch  2500 | loss 3.321e-01
# [window 14] [Adam]  epoch  3000 | loss 3.736e-02
# [window 14] [Adam]  epoch  3500 | loss 4.107e-02
# [window 14] [Adam]  epoch  4000 | loss 1.449e-02
# [window 15] [Adam]  epoch     0 | loss 1.310e-02
# [window 15] [Adam]  epoch   500 | loss 7.545e-03
# [window 15] [Adam]  epoch  1000 | loss 1.174e-02
# [window 15] [Adam]  epoch  1500 | loss 8.107e-03
# [window 15] [Adam]  epoch  2000 | loss 7.996e-03
# [window 15] [Adam]  epoch  2500 | loss 9.913e-03
# [window 15] [Adam]  epoch  3000 | loss 9.111e-03
# [window 15] [Adam]  epoch  3500 | loss 8.746e-03
# [window 15] [Adam]  epoch  4000 | loss 1.111e-02
# [window 16] [Adam]  epoch     0 | loss 1.205e-01
# [window 16] [Adam]  epoch   500 | loss 1.148e-02
# [window 16] [Adam]  epoch  1000 | loss 7.337e-03
# [window 16] [Adam]  epoch  1500 | loss 1.654e-02
# [window 16] [Adam]  epoch  2000 | loss 8.999e-03
# [window 16] [Adam]  epoch  2500 | loss 2.261e-02
# [window 16] [Adam]  epoch  3000 | loss 1.086e-02
# [window 16] [Adam]  epoch  3500 | loss 5.598e-03
# [window 16] [Adam]  epoch  4000 | loss 2.664e-02
# [window 16] [L-BFGS] iter   500 | loss 5.007e-06
# [window 16] [L-BFGS] iter  1000 | loss 5.005e-06
# [window 16] [L-BFGS] iter  1500 | loss 5.003e-06
# [window 16] [L-BFGS] iter  2000 | loss 5.001e-06
# [window 16] [L-BFGS] iter  2500 | loss 4.999e-06
# [window 17] [Adam]  epoch     0 | loss 7.505e+01
# [window 17] [Adam]  epoch   500 | loss 6.531e-01
# [window 17] [Adam]  epoch  1000 | loss 7.372e-01
# [window 17] [Adam]  epoch  1500 | loss 5.217e-01
# [window 17] [Adam]  epoch  2000 | loss 4.583e-01
# [window 17] [Adam]  epoch  2500 | loss 2.647e-01
# [window 17] [L-BFGS] iter   500 | loss 9.913e-05
# [window 17] [L-BFGS] iter  1000 | loss 7.879e-06
# [window 17] [L-BFGS] iter  1500 | loss 3.903e-06
# [window 17] [L-BFGS] iter  2000 | loss 3.522e-06
# [window 18] [Adam]  epoch     0 | loss 7.978e+06
# [window 18] [Adam]  epoch   500 | loss 7.036e+01
# [window 18] [Adam]  epoch  1000 | loss 3.668e+01
# [window 18] [Adam]  epoch  1500 | loss 2.103e+01
# [window 18] [Adam]  epoch  2000 | loss 1.351e+01
# [window 18] [Adam]  epoch  2500 | loss 1.062e+01
# [window 18] [L-BFGS] iter   500 | loss 6.344e-03
# [window 18] [L-BFGS] iter  1000 | loss 1.970e-03
# [window 18] [L-BFGS] iter  1500 | loss 6.655e-04
# [window 18] [L-BFGS] iter  2000 | loss 1.814e-04
# [window 18] loss 1.227e-04 > 1.0e-04 threshold -> retry 1/2
# [window 18] [L-BFGS-retry1] iter   500 | loss 3.862e-05
# [window 18] [L-BFGS-retry1] iter  1000 | loss 3.861e-05
# [window 18] [L-BFGS-retry1] iter  1500 | loss 3.861e-05
# [window 18] [L-BFGS-retry1] iter  2000 | loss 3.860e-05
# [window 18] [L-BFGS-retry1] iter  2500 | loss 3.859e-05
# [window 19] [Adam]  epoch     0 | loss 2.004e+16
# [window 19] [Adam]  epoch   500 | loss 3.076e+01
# [window 19] [Adam]  epoch  1000 | loss 3.970e+01
# [window 19] [Adam]  epoch  1500 | loss 7.272e+01
# [window 19] [Adam]  epoch  2000 | loss 1.687e+02
# [window 19] [Adam]  epoch  2500 | loss 1.059e+01
# [window 19] [Adam]  epoch  3000 | loss 2.209e+02
# [window 19] [L-BFGS] iter   500 | loss 1.417e-02
# [window 19] [L-BFGS] iter  1000 | loss 2.123e-03
# [window 19] [L-BFGS] iter  1500 | loss 5.239e-04
# [window 19] [L-BFGS] iter  2000 | loss 9.603e-05
# [window 19] [L-BFGS] iter  2500 | loss 2.587e-05
# [window 20] [Adam]  epoch     0 | loss 1.507e+01
# [window 20] [Adam]  epoch   500 | loss 1.872e+02
# [window 20] [Adam]  epoch  1000 | loss 3.496e+01
# [window 20] [Adam]  epoch  1500 | loss 1.903e+02
# [window 20] [Adam]  epoch  2000 | loss 3.001e+00
# [window 20] [Adam]  epoch  2500 | loss 1.468e+01
# [window 20] [Adam]  epoch  3000 | loss 1.086e+01
# Time-marching training complete in 1090.7s.

# %%
t_eval = np.linspace(0, T_FINAL, 2000)
sol = solve_ivp(van_der_pol_rhs, [0, T_FINAL], [X0, V0], t_eval=t_eval, method="RK45", rtol=1e-10, atol=1e-10)
x_reference = sol.y[0]
v_reference = sol.y[1]

x_pred = np.zeros_like(t_eval)
for w, model_w in enumerate(models):
    t_start = window_edges[w]
    t_end = window_edges[w + 1]
    mask = (t_eval >= t_start) & (t_eval <= t_end + 1e-9)
    if not np.any(mask):
        continue
    t_local = torch.tensor(t_eval[mask].reshape(-1, 1), dtype=torch.get_default_dtype(), device=device)
    with torch.no_grad():
        x_local = model_w(t_local).cpu().numpy().flatten()
    x_pred[mask] = x_local

# %%
mse = np.mean((x_pred - x_reference) ** 2)
relative_l2_error = np.linalg.norm(x_pred - x_reference) / np.linalg.norm(x_reference)
final_training_loss = full_history[-1]
n_params = sum(p.numel() for p in models[0].parameters())

# New metrics
mae = np.mean(np.abs(x_pred - x_reference))
max_error = np.max(np.abs(x_pred - x_reference))
rmse = np.sqrt(mse)

t_res_test = torch.tensor(
    np.random.uniform(0.0, T_FINAL, size=(2000, 1)),
    dtype=torch.get_default_dtype(), device=device,
)
residual_vals = []
per_window_final_loss = []
for w, model_w in enumerate(models):
    t_start = window_edges[w]
    t_end = window_edges[w + 1]
    mask = (t_res_test.detach().cpu().numpy().flatten() >= t_start) & \
           (t_res_test.detach().cpu().numpy().flatten() <= t_end)
    if np.any(mask):
        t_sub = t_res_test[mask].clone().detach().requires_grad_(True)
        f_sub = physics_residual(model_w, t_sub)
        residual_vals.append(f_sub.detach().cpu().numpy())
mean_physics_residual = np.mean(np.concatenate(residual_vals) ** 2) if residual_vals else float("nan")

print(f"MSE: {mse:.3e}")
print(f"Relative L2 error: {relative_l2_error:.3e}")
print(f"Final training loss: {final_training_loss:.3e}")
print(f"Mean physics residual (test points): {mean_physics_residual:.3e}")
print(f"Training time: {training_time:.1f}s")
print(f"Trainable parameters (per window model): {n_params}")
print(f"Windows: {n_windows_actual}")
# Print new metrics
print(f"MAE: {mae:.3e}")
print(f"Max Error (L_inf): {max_error:.3e}")
print(f"RMSE: {rmse:.3e}")
# Out:
# MSE: 5.705e-05
# Relative L2 error: 4.517e-03
# Final training loss: 9.448e-06
# Mean physics residual (test points): 2.089e-05
# Training time: 1090.7s
# Trainable parameters (per window model): 3265
# Windows: 21
# MAE: 8.732e-04
# Max Error (L_inf): 1.797e-01
# RMSE: 7.553e-03

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 9))

axes[0, 0].plot(t_eval, x_reference, "b-", linewidth=2, label="Reference (RK45)")
axes[0, 0].plot(t_eval, x_pred, "r--", linewidth=2, label="PINN prediction (time-marched)")
for edge in window_edges[1:-1]:
    axes[0, 0].axvline(edge, color="gray", linestyle=":", linewidth=0.7)
axes[0, 0].set_xlabel("t")
axes[0, 0].set_ylabel("x(t)")
axes[0, 0].set_title("Van der Pol oscillator: PINN vs. reference (non-uniform windows)")
axes[0, 0].legend()

axes[0, 1].semilogy(full_history, label="physics residual loss")
axes[0, 1].set_xlabel("iteration (concatenated across windows)")
axes[0, 1].set_ylabel("loss (log scale)")
axes[0, 1].set_title("Training loss history")
axes[0, 1].legend()

axes[1, 0].plot(t_eval, np.abs(x_pred - x_reference), "k-")
for edge in window_edges[1:-1]:
    axes[1, 0].axvline(edge, color="gray", linestyle=":", linewidth=0.7)
axes[1, 0].set_xlabel("t")
axes[1, 0].set_ylabel("|x_pred - x_reference|")
axes[1, 0].set_title("Absolute error")

x_pred_dot = np.gradient(x_pred, t_eval)
axes[1, 1].plot(x_reference, v_reference, "b-", linewidth=2, label="Reference")
axes[1, 1].plot(x_pred, x_pred_dot, "r--", linewidth=2, label="PINN prediction")
axes[1, 1].set_xlabel("x")
axes[1, 1].set_ylabel("x'")
axes[1, 1].set_title("Phase portrait")
axes[1, 1].legend()

plt.tight_layout()
plt.savefig("pinn_van_der_pol_adaptive_v2_results.png", dpi=150)
plt.show()

# %%
fig2, ax2 = plt.subplots(figsize=(9, 3.5))
ax2.plot(coarse_t, coarse_monitor, "b-", linewidth=1.2, label="monitor (weighted |v| + |accel|)")
for edge in window_edges:
    ax2.axvline(edge, color="gray", linestyle=":", linewidth=0.7)
ax2.set_xlabel("t")
ax2.set_ylabel("monitor value")
ax2.set_title("Window placement: dense near fast transitions, sparse in slow regions")
ax2.legend()
plt.tight_layout()
plt.savefig("window_placement_diagnostic_v2.png", dpi=150)
plt.show()
