# %%
import time
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.set_default_dtype(torch.float64)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

MU = 40.0  # nonlinearity factor
X0 = 1.0  # initial position x(0)
V0 = 0.0  # initial velocity x'(0)

PERIOD_MARGIN = 1.15
ROUGH_PERIOD_FACTOR = 1.614
N_PERIODS_SETTLE = 4

N_WINDOWS_TARGET = 10  # initial equidistribution target: actual count may grow via MAX_WIDTH splitting
LAYERS = (1, 32, 32, 32, 32, 1)  # shared depth/width; input dim replaced by 2*mapping_size in the Fourier encoder
N_COLLOCATION_PER_WINDOW = 2000
COLLOCATION_SCALE_CAP = 3.0
ADAM_EPOCHS = 3000
ADAM_LR = 1e-3
GRAD_CLIP_NORM = 10.0
LBFGS_MAX_ITER = 2000
PRINT_EVERY = 500

# Adaptive collocation resampling (same values as the Standard PINN / SIREN v2)
RESAMPLE_EVERY = 500
RESAMPLE_CANDIDATE_MULT = 5
RESAMPLE_UNIFORM_FLOOR = 0.2

# Non-uniform window placement -- MIN/MAX match Stephen's Standard PINN exactly
COARSE_N_POINTS = 4000
MIN_WINDOW_WIDTH = 0.15
MAX_WINDOW_WIDTH = 3.0
MONITOR_VELOCITY_WEIGHT = 0.4
MONITOR_ACCEL_WEIGHT = 0.6

# Convergence retry
LOSS_CONVERGENCE_THRESHOLD = 1e-4
MAX_RETRIES_PER_WINDOW = 2

# Fourier-specific: joint sigma / mapping-size sweep
FOURIER_MAPPING_SIZE = 16
FOURIER_SIGMA = 5.0
SIGMA_CANDIDATES = [0.5, 1, 2, 5, 10, 20, 30]
MAPPING_SIZE_CANDIDATES = [12, 16, 32]
SIGMA_PROBE_EPOCHS = 800
# Out:
# Using device: cuda

# %%
def van_der_pol_rhs(t, y, mu=MU):
    x, v = y
    return [v, mu * (1 - x ** 2) * v - x]

def estimate_vdp_period(mu, x0=X0, v0=V0, rough_factor=ROUGH_PERIOD_FACTOR, n_settle=N_PERIODS_SETTLE):
    rough_T = rough_factor * mu
    t_span = n_settle * max(rough_T, 5.0)

    def event_peak(t, y):
        return y[1]
    event_peak.direction = -1

    sol = solve_ivp(
        lambda t, y: van_der_pol_rhs(t, y, mu=mu),
        [0.0, t_span], [x0, v0],
        events=event_peak, rtol=1e-10, atol=1e-12, max_step=0.05,
    )
    peak_times = sol.t_events[0]
    if len(peak_times) < 3:
        print(f"[period detection] not enough peaks found, falling back to rough estimate {rough_T:.3f}")
        return rough_T
    return peak_times[-1] - peak_times[-2]


vdp_period = estimate_vdp_period(MU)
T_FINAL = float(PERIOD_MARGIN * vdp_period)
print(f"Detected VdP period at mu={MU}: {vdp_period:.4f}  ->  T_FINAL = {T_FINAL:.4f}")
# Out:
# Detected VdP period at mu=40.0: 66.5014  ->  T_FINAL = 76.4766

# %%
class BasePINN(nn.Module):
    # Shared architecture skeleton: encode_input() + trunk_forward()

    def __init__(self):
        super().__init__()

    def encode_input(self, t):
        raise NotImplementedError

    def trunk_forward(self, encoded):
        raise NotImplementedError

    def forward(self, t):
        return self.trunk_forward(self.encode_input(t))

    @staticmethod
    def init_linear(linear):
        nn.init.xavier_normal_(linear.weight)
        nn.init.zeros_(linear.bias)

# %%
class FourierFeaturePINN(BasePINN):
    """
    Random Fourier Feature PINN (Tancik et al.). encode_input() normalizes t
    into [-1, 1] over this window, then maps it through a fixed random
    frequency matrix B: gamma(t) = [cos(2*pi*B*t), sin(2*pi*B*t)].
    trunk_forward() is the same tanh MLP shape as the Standard PINN, with the
    input layer sized for 2*mapping_size instead of 1.
    """

    def __init__(self, t_start, window_size, layers=LAYERS,
                 mapping_size=FOURIER_MAPPING_SIZE, sigma=FOURIER_SIGMA, B=None):
        super().__init__()
        self.t_start = t_start
        self.window_size = window_size
        self.mapping_size = mapping_size
        self.sigma = sigma

        if B is None:
            B = torch.randn(1, mapping_size) * sigma
        else:
            B = B.clone().detach()
        self.register_buffer("B", B)

        fourier_layers = (2 * mapping_size,) + tuple(layers[1:])
        self.trunk = nn.ModuleList()
        for i in range(len(fourier_layers) - 1):
            linear = nn.Linear(fourier_layers[i], fourier_layers[i + 1])
            self.init_linear(linear)
            self.trunk.append(linear)
        self.activation = torch.tanh

    def encode_input(self, t):
        tau = t - self.t_start
        t_norm = (2.0 * tau / self.window_size) - 1.0
        proj = 2.0 * np.pi * (t_norm @ self.B)
        return torch.cat([torch.cos(proj), torch.sin(proj)], dim=-1)

    def trunk_forward(self, encoded):
        out = encoded
        for layer in self.trunk[:-1]:
            out = self.activation(layer(out))
        return self.trunk[-1](out)

# %%
class WindowPINN(nn.Module):
    """
    Time-marching wrapper, wraps base architecture (FourierFeaturePinn) and enforces this window's initial condition exactly:
    x(t) = x0_local + v0_local * tau + tau^2 * base_model(t)
    """
    def __init__(self, base_model, t_start, window_size, x0_local, v0_local):
        super().__init__()
        self.base_model = base_model
        self.t_start = t_start
        self.window_size = window_size
        self.x0_local = x0_local
        self.v0_local = v0_local

    def forward(self, t):
        tau = t - self.t_start
        n_raw = self.base_model(t)
        return self.x0_local + self.v0_local * tau + (tau ** 2) * n_raw

# %%
def physics_residual(model, t, mu=MU):
    x = model(t)
    x_t = torch.autograd.grad(x, t, grad_outputs=torch.ones_like(x), create_graph=True, retain_graph=True)[0]
    x_tt = torch.autograd.grad(x_t, t, grad_outputs=torch.ones_like(x_t), create_graph=True, retain_graph=True)[0]
    return x_tt - mu * (1.0 - x ** 2) * x_t + x

def compute_loss(model, t_f):
    # only the physics residual; IC is hard-enforced, no loss_ic term
    f_pred = physics_residual(model, t_f)
    return torch.mean(f_pred ** 2)

def sample_collocation_points(t_start, t_end, n):
    t_f = np.random.uniform(low=t_start, high=t_end, size=(n, 1))
    t_f = torch.tensor(t_f, dtype=torch.get_default_dtype(), device=device)
    t_f.requires_grad_(True)
    return t_f

def evaluate_state(model, t_value):
    # (x, x') of a trained window model at a single time becomes the hard IC handed to the next window
    t_tensor = torch.tensor([[t_value]], dtype=torch.get_default_dtype(), device=device, requires_grad=True)
    x = model(t_tensor)
    x_t = torch.autograd.grad(x, t_tensor, grad_outputs=torch.ones_like(x))[0]
    return x.item(), x_t.item()

# %%
def adaptive_collocation_points(model, t_start, t_end, n_points, n_candidates_mult=RESAMPLE_CANDIDATE_MULT, uniform_floor=RESAMPLE_UNIFORM_FLOOR):
    n_candidates = max(n_points * n_candidates_mult, n_points)
    t_candidates_np = np.random.uniform(t_start, t_end, size=(n_candidates, 1))
    t_candidates = torch.tensor(t_candidates_np, dtype=torch.get_default_dtype(), device=device)
    t_candidates.requires_grad_(True)
    residual = physics_residual(model, t_candidates)
    scores = (residual.detach() ** 2).cpu().numpy().flatten()
    scores += 1e-12
    probs = scores / scores.sum()
    n_weighted = int(round(n_points * (1.0 - uniform_floor)))
    n_uniform = n_points - n_weighted
    weighted_idx = np.random.choice(n_candidates, size=n_weighted, replace=False, p=probs)
    t_weighted_np = t_candidates_np[weighted_idx]
    t_uniform_np = np.random.uniform(t_start, t_end, size=(n_uniform, 1))
    t_new_np = np.vstack([t_weighted_np, t_uniform_np])
    t_new = torch.tensor(t_new_np, dtype=torch.get_default_dtype(), device=device)
    t_new.requires_grad_(True)
    return t_new

def compute_nonuniform_window_edges(n_windows, t_final=T_FINAL, mu=MU, x0=X0, v0=V0, coarse_n_points=COARSE_N_POINTS, min_width=MIN_WINDOW_WIDTH, max_width=MAX_WINDOW_WIDTH):
    t_coarse = np.linspace(0.0, t_final, coarse_n_points)
    sol = solve_ivp(lambda t, y: van_der_pol_rhs(t, y, mu=mu), [0.0, t_final], [x0, v0], t_eval=t_coarse, method="RK45", rtol=1e-9, atol=1e-9)
    x_c, v_c = sol.y[0], sol.y[1]
    accel = mu * (1 - x_c ** 2) * v_c - x_c
    vel_norm = np.abs(v_c) / (np.abs(v_c).max() + 1e-12)
    acc_norm = np.abs(accel) / (np.abs(accel).max() + 1e-12)
    monitor = MONITOR_VELOCITY_WEIGHT * vel_norm + MONITOR_ACCEL_WEIGHT * acc_norm
    cumulative = np.concatenate([[0.0], np.cumsum(0.5 * (monitor[1:] + monitor[:-1]) * np.diff(t_coarse))])
    total_measure = cumulative[-1]
    targets = np.linspace(0.0, total_measure, n_windows + 1)
    edges = np.interp(targets, cumulative, t_coarse)
    edges[0], edges[-1] = 0.0, t_final
    # forward pass: enforce MIN_WINDOW_WIDTH left to right
    for i in range(1, len(edges) - 1):
        if edges[i] - edges[i - 1] < min_width:
            edges[i] = edges[i - 1] + min_width
    edges = np.clip(edges, 0.0, t_final)
    edges[-1] = t_final
    # backward pass: re-enforce from the right so the last window can't collapse below the floor
    for i in range(len(edges) - 2, 0, -1):
        if edges[i + 1] - edges[i] < min_width:
            edges[i] = edges[i + 1] - min_width
    edges = np.clip(edges, 0.0, t_final)
    edges[0], edges[-1] = 0.0, t_final
    edges = np.unique(edges)
    new_edges = [edges[0]]
    for i in range(len(edges) - 1):
        a, b = edges[i], edges[i + 1]
        width = b - a
        n_sub = max(int(np.ceil(width / max_width)), 1)
        sub_edges = np.linspace(a, b, n_sub + 1)[1:]
        new_edges.extend(sub_edges.tolist())
    edges = np.unique(np.array(new_edges))
    return edges, t_coarse, monitor

# %%
def run_adam_phase(model, t_start, t_end, n_points, adam_epochs, window_idx, tag="Adam"):
    t_f = sample_collocation_points(t_start, t_end, n_points)
    history = []
    optimizer = torch.optim.Adam(model.parameters(), lr=ADAM_LR)
    for epoch in range(adam_epochs):
        if epoch > 0 and epoch % RESAMPLE_EVERY == 0:
            t_f = adaptive_collocation_points(model, t_start, t_end, n_points)
        optimizer.zero_grad()
        loss = compute_loss(model, t_f)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), GRAD_CLIP_NORM)
        optimizer.step()
        history.append(loss.item())
        if epoch % PRINT_EVERY == 0:
            print(f"[window {window_idx}] [{tag}]  epoch {epoch:5d} | loss {loss.item():.3e}")
    return history, t_f

def run_lbfgs_phase(model, t_f, max_iter, window_idx, tag="L-BFGS"):
    history = []
    optimizer_lbfgs = torch.optim.LBFGS(model.parameters(), max_iter=max_iter, tolerance_grad=1e-9, tolerance_change=1e-12, history_size=50, line_search_fn="strong_wolfe")
    counter = {"n": 0}
    def closure():
        optimizer_lbfgs.zero_grad()
        loss = compute_loss(model, t_f)
        loss.backward()
        history.append(loss.item())
        counter["n"] += 1
        if counter["n"] % PRINT_EVERY == 0:
            print(f"[window {window_idx}] [{tag}] iter {counter['n']:5d} | loss {loss.item():.3e}")
        return loss

    optimizer_lbfgs.step(closure)
    return history

# %%
def train_window(model, t_start, t_end, n_points, adam_epochs, window_idx=0):
    history, t_f = run_adam_phase(model, t_start, t_end, n_points, adam_epochs, window_idx, tag="Adam")
    t_f = adaptive_collocation_points(model, t_start, t_end, n_points)
    history += run_lbfgs_phase(model, t_f, LBFGS_MAX_ITER, window_idx, tag="L-BFGS")
    retries = 0
    while history[-1] > LOSS_CONVERGENCE_THRESHOLD and retries < MAX_RETRIES_PER_WINDOW:
        retries += 1
        print(f"[window {window_idx}] loss {history[-1]:.3e} > {LOSS_CONVERGENCE_THRESHOLD:.1e} threshold "
              f"-> retry {retries}/{MAX_RETRIES_PER_WINDOW}")
        t_f = adaptive_collocation_points(model, t_start, t_end, n_points)
        history += run_lbfgs_phase(model, t_f, LBFGS_MAX_ITER, window_idx, tag=f"L-BFGS-retry{retries}")

    return history

# %%
window_edges, coarse_t, coarse_monitor = compute_nonuniform_window_edges(N_WINDOWS_TARGET)
window_widths = np.diff(window_edges)
n_windows_actual = len(window_widths)
mean_width = window_widths.mean()
print(f"Non-uniform window edges (t): {np.round(window_edges, 3)}")
print(f"Window widths: {np.round(window_widths, 3)}")
print(f"Actual window count after MAX_WIDTH splitting: {n_windows_actual} (target was {N_WINDOWS_TARGET})")
# Out:
# Non-uniform window edges (t): [ 0.     0.579  0.729  0.879  3.867  6.854  9.842 12.83  15.818 18.805
#  21.793 24.781 27.768 30.756 33.744 33.894 34.044 36.886 39.728 42.57
#  45.412 48.254 51.095 53.937 56.779 59.621 62.463 64.742 67.021 67.171
#  69.497 71.824 74.15  76.477]
# Window widths: [0.579 0.15  0.15  2.988 2.988 2.988 2.988 2.988 2.988 2.988 2.988 2.988
#  2.988 2.988 0.15  0.15  2.842 2.842 2.842 2.842 2.842 2.842 2.842 2.842
#  2.842 2.842 2.279 2.279 0.15  2.326 2.326 2.326 2.326]
# Actual window count after MAX_WIDTH splitting: 33 (target was 10)

# %%
def quick_pinn_probe(sigma, mapping_size, t_f, t_start, window_size, adam_epochs=SIGMA_PROBE_EPOCHS):
    torch.manual_seed(SEED)
    base = FourierFeaturePINN(t_start, window_size, mapping_size=mapping_size, sigma=sigma).to(device)
    model_w = WindowPINN(base, t_start, window_size, X0, V0).to(device)
    opt = torch.optim.Adam(model_w.parameters(), lr=ADAM_LR)
    loss = None
    for _ in range(adam_epochs):
        opt.zero_grad()
        loss = compute_loss(model_w, t_f)
        loss.backward()
        opt.step()
    return loss.item()

print("\n - Joint sigma / mapping-size sweep (multiple representative windows) - ")
probe_indices = sorted(set([0, n_windows_actual // 2, n_windows_actual - 1]))
probe_windows = [(int(window_edges[i]), float(window_edges[i]), float(window_widths[i])) for i in probe_indices]
probe_t_fs = {
    i: sample_collocation_points(window_edges[i], window_edges[i + 1], N_COLLOCATION_PER_WINDOW)
    for i in probe_indices
}

combo_losses = {}
for mapping_size_candidate in MAPPING_SIZE_CANDIDATES:
    for sigma_candidate in SIGMA_CANDIDATES:
        window_losses = [
            quick_pinn_probe(sigma_candidate, mapping_size_candidate, probe_t_fs[i],
                              t_start=float(window_edges[i]), window_size=float(window_widths[i]))
            for i in probe_indices
        ]
        avg_loss = float(np.mean(window_losses))
        combo_losses[(sigma_candidate, mapping_size_candidate)] = avg_loss
        per_window_str = ", ".join(f"{l:.2e}" for l in window_losses)
        print(f"  sigma={sigma_candidate:>5} mapping_size={mapping_size_candidate:>3} "
              f"-> avg probe loss {avg_loss:.3e}  (per-window: {per_window_str})")

FOURIER_SIGMA, FOURIER_MAPPING_SIZE = min(combo_losses, key=combo_losses.get)
print(f"- Selected FOURIER_SIGMA = {FOURIER_SIGMA}, FOURIER_MAPPING_SIZE = {FOURIER_MAPPING_SIZE} -\n")

np.random.seed(SEED)
torch.manual_seed(SEED)
shared_B = (torch.randn(1, FOURIER_MAPPING_SIZE) * FOURIER_SIGMA).to(device)
# Out:
#  - Joint sigma / mapping-size sweep (multiple representative windows) -
#   sigma=  0.5 mapping_size= 12 -> avg probe loss 3.381e+00  (per-window: 1.19e-01, 8.64e+00, 1.38e+00)
#   sigma=    1 mapping_size= 12 -> avg probe loss 6.373e+00  (per-window: 1.63e-01, 3.36e+00, 1.56e+01)
#   sigma=    2 mapping_size= 12 -> avg probe loss 5.195e+02  (per-window: 8.32e-01, 7.76e+02, 7.82e+02)
#   sigma=    5 mapping_size= 12 -> avg probe loss 2.909e+02  (per-window: 9.10e+01, 6.54e+02, 1.28e+02)
#   sigma=   10 mapping_size= 12 -> avg probe loss 8.567e+03  (per-window: 1.83e+03, 1.89e+04, 4.97e+03)
#   sigma=   20 mapping_size= 12 -> avg probe loss 8.233e+04  (per-window: 5.58e+04, 1.24e+05, 6.73e+04)
#   sigma=   30 mapping_size= 12 -> avg probe loss 4.984e+05  (per-window: 2.80e+05, 8.04e+05, 4.10e+05)
#   sigma=  0.5 mapping_size= 16 -> avg probe loss 1.221e+00  (per-window: 9.60e-02, 2.43e+00, 1.14e+00)
#   sigma=    1 mapping_size= 16 -> avg probe loss 1.494e+01  (per-window: 3.13e-01, 3.64e+01, 8.09e+00)
#   sigma=    2 mapping_size= 16 -> avg probe loss 9.021e+02  (per-window: 2.35e+00, 1.42e+03, 1.28e+03)
#   sigma=    5 mapping_size= 16 -> avg probe loss 2.380e+03  (per-window: 1.63e+02, 5.69e+03, 1.29e+03)
#   sigma=   10 mapping_size= 16 -> avg probe loss 7.900e+04  (per-window: 3.83e+03, 1.97e+05, 3.58e+04)
#   sigma=   20 mapping_size= 16 -> avg probe loss 5.126e+05  (per-window: 1.31e+05, 1.10e+06, 3.07e+05)
#   sigma=   30 mapping_size= 16 -> avg probe loss 1.030e+06  (per-window: 5.22e+05, 1.88e+06, 6.84e+05)
#   sigma=  0.5 mapping_size= 32 -> avg probe loss 6.700e-01  (per-window: 6.72e-02, 1.10e+00, 8.47e-01)
#   sigma=    1 mapping_size= 32 -> avg probe loss 4.829e+00  (per-window: 1.82e-01, 1.07e+01, 3.63e+00)
#   sigma=    2 mapping_size= 32 -> avg probe loss 2.169e+02  (per-window: 1.64e+00, 6.39e+02, 1.05e+01)
#   sigma=    5 mapping_size= 32 -> avg probe loss 2.776e+03  (per-window: 5.33e+01, 6.96e+03, 1.31e+03)
#   sigma=   10 mapping_size= 32 -> avg probe loss 6.306e+03  (per-window: 2.44e+03, 1.32e+04, 3.31e+03)
#   sigma=   20 mapping_size= 32 -> avg probe loss 9.666e+04  (per-window: 6.40e+04, 1.59e+05, 6.67e+04)
#   sigma=   30 mapping_size= 32 -> avg probe loss 4.826e+05  (per-window: 3.22e+05, 7.13e+05, 4.12e+05)
# - Selected FOURIER_SIGMA = 0.5, FOURIER_MAPPING_SIZE = 32 -

# %%
start_time = time.time()
models = []
full_history = []
x0_cur, v0_cur = X0, V0
prev_base_state = None

for w in range(n_windows_actual):
    t_start = float(window_edges[w])
    t_end = float(window_edges[w + 1])
    width = t_end - t_start
    # scale collocation points and Adam epochs by window width relative to the mean
    width_ratio = width / mean_width
    n_points_w = int(round(N_COLLOCATION_PER_WINDOW * np.clip(width_ratio, 1.0, COLLOCATION_SCALE_CAP)))
    adam_epochs_w = int(round(ADAM_EPOCHS * np.clip(width_ratio, 1.0, 2.0)))

    base = FourierFeaturePINN(t_start, width, mapping_size=FOURIER_MAPPING_SIZE,
                               sigma=FOURIER_SIGMA, B=shared_B).to(device)
    if prev_base_state is not None:
        base.load_state_dict(prev_base_state)  # warm start from previous window

    model_w = WindowPINN(base, t_start, width, x0_cur, v0_cur).to(device)
    hist = train_window(model_w, t_start, t_end, n_points_w, adam_epochs_w, window_idx=w)
    full_history.extend(hist)

    x0_cur, v0_cur = evaluate_state(model_w, t_end)
    models.append(model_w)
    prev_base_state = base.state_dict()

training_time = time.time() - start_time
print(f"Time-marching training complete in {training_time:.1f}s.")
# Out:
# [window 0] [Adam]  epoch     0 | loss 8.467e+01
# [window 0] [Adam]  epoch   500 | loss 2.176e-01
# [window 0] [Adam]  epoch  1000 | loss 2.328e-01
# [window 0] [Adam]  epoch  1500 | loss 2.439e-01
# [window 0] [Adam]  epoch  2000 | loss 3.117e-01
# [window 0] [Adam]  epoch  2500 | loss 2.681e-01
# [window 0] [L-BFGS] iter   500 | loss 1.372e-03
# [window 0] [L-BFGS] iter  1000 | loss 1.502e-04
# [window 0] [L-BFGS] iter  1500 | loss 3.040e-05
# [window 0] [L-BFGS] iter  2000 | loss 1.114e-05
# [window 1] [Adam]  epoch     0 | loss 1.332e+08
# [window 1] [Adam]  epoch   500 | loss 5.799e+07
# [window 1] [Adam]  epoch  1000 | loss 6.997e+08
# [window 1] [Adam]  epoch  1500 | loss 5.504e+07
# [window 1] [Adam]  epoch  2000 | loss 9.963e+08
# [window 1] [Adam]  epoch  2500 | loss 1.667e+09
# [window 1] [L-BFGS] iter   500 | loss 6.385e+04
# [window 1] [L-BFGS] iter  1000 | loss 3.214e+04
# [window 1] [L-BFGS] iter  1500 | loss 2.693e+04
# [window 1] [L-BFGS] iter  2000 | loss 2.485e+04
# [window 1] loss 2.181e+04 > 1.0e-04 threshold -> retry 1/2
# [window 1] [L-BFGS-retry1] iter   500 | loss 5.048e+05
# [window 1] [L-BFGS-retry1] iter  1000 | loss 3.353e+05
# [window 1] [L-BFGS-retry1] iter  1500 | loss 3.084e+05
# [window 1] [L-BFGS-retry1] iter  2000 | loss 2.493e+05
# [window 1] loss 2.296e+05 > 1.0e-04 threshold -> retry 2/2
# [window 1] [L-BFGS-retry2] iter   500 | loss 1.766e+05
# [window 1] [L-BFGS-retry2] iter  1000 | loss 1.692e+05
# [window 1] [L-BFGS-retry2] iter  1500 | loss 1.631e+05
# [window 1] [L-BFGS-retry2] iter  2000 | loss 1.568e+05
# [window 2] [Adam]  epoch     0 | loss 2.399e+07
# [window 2] [Adam]  epoch   500 | loss 7.787e+05
# [window 2] [Adam]  epoch  1000 | loss 3.784e+06
# [window 2] [Adam]  epoch  1500 | loss 2.873e+05
# [window 2] [Adam]  epoch  2000 | loss 1.459e+05
# [window 2] [Adam]  epoch  2500 | loss 1.513e+03
# [window 2] [L-BFGS] iter   500 | loss 3.600e-01
# [window 2] [L-BFGS] iter  1000 | loss 8.780e-02
# [window 2] [L-BFGS] iter  1500 | loss 2.550e-02
# [window 2] [L-BFGS] iter  2000 | loss 1.442e-02
# [window 2] loss 1.294e-02 > 1.0e-04 threshold -> retry 1/2
# [window 2] [L-BFGS-retry1] iter   500 | loss 1.327e-02
# [window 2] [L-BFGS-retry1] iter  1000 | loss 5.571e-03
# [window 2] [L-BFGS-retry1] iter  1500 | loss 3.464e-03
# [window 2] [L-BFGS-retry1] iter  2000 | loss 1.884e-03
# [window 2] loss 1.676e-03 > 1.0e-04 threshold -> retry 2/2
# [window 2] [L-BFGS-retry2] iter   500 | loss 1.855e-03
# [window 2] [L-BFGS-retry2] iter  1000 | loss 1.407e-03
# [window 2] [L-BFGS-retry2] iter  1500 | loss 1.155e-03
# [window 2] [L-BFGS-retry2] iter  2000 | loss 1.034e-03
# [window 3] [Adam]  epoch     0 | loss 1.520e+09
# [window 3] [Adam]  epoch   500 | loss 1.842e+03
# [window 3] [Adam]  epoch  1000 | loss 2.015e+03
# [window 3] [Adam]  epoch  1500 | loss 2.674e+03
# [window 3] [Adam]  epoch  2000 | loss 2.241e+03
# [window 3] [Adam]  epoch  2500 | loss 1.873e+03
# [window 3] [Adam]  epoch  3000 | loss 4.228e+03
# [window 3] [Adam]  epoch  3500 | loss 1.281e+03
# [window 3] [L-BFGS] iter   500 | loss 9.762e+01
# [window 3] [L-BFGS] iter  1000 | loss 9.333e+01
# [window 3] [L-BFGS] iter  1500 | loss 9.112e+01
# [window 3] [L-BFGS] iter  2000 | loss 8.888e+01
# [window 3] loss 8.725e+01 > 1.0e-04 threshold -> retry 1/2
# [window 3] [L-BFGS-retry1] iter   500 | loss 1.050e+02
# [window 3] [L-BFGS-retry1] iter  1000 | loss 8.515e+01
# [window 3] [L-BFGS-retry1] iter  1500 | loss 6.259e+01
# [window 3] [L-BFGS-retry1] iter  2000 | loss 2.886e+01
# [window 3] loss 1.559e+01 > 1.0e-04 threshold -> retry 2/2
# [window 3] [L-BFGS-retry2] iter   500 | loss 7.269e+01
# [window 3] [L-BFGS-retry2] iter  1000 | loss 7.117e+01
# [window 3] [L-BFGS-retry2] iter  1500 | loss 7.035e+01
# [window 3] [L-BFGS-retry2] iter  2000 | loss 6.912e+01
# [window 4] [Adam]  epoch     0 | loss 1.805e+07
# [window 4] [Adam]  epoch   500 | loss 1.562e+02
# [window 4] [Adam]  epoch  1000 | loss 1.478e+02
# [window 4] [Adam]  epoch  1500 | loss 1.197e+02
# [window 4] [Adam]  epoch  2000 | loss 6.801e+01
# [window 4] [Adam]  epoch  2500 | loss 1.844e+02
# [window 4] [Adam]  epoch  3000 | loss 1.660e+01
# [window 4] [Adam]  epoch  3500 | loss 1.053e+01
# [window 4] [L-BFGS] iter   500 | loss 6.576e-03
# [window 4] [L-BFGS] iter  1000 | loss 2.463e-03
# [window 4] [L-BFGS] iter  1500 | loss 1.089e-03
# [window 4] [L-BFGS] iter  2000 | loss 7.100e-04
# [window 4] loss 6.622e-04 > 1.0e-04 threshold -> retry 1/2
# [window 4] [L-BFGS-retry1] iter   500 | loss 1.486e-03
# [window 4] [L-BFGS-retry1] iter  1000 | loss 5.281e-04
# [window 4] [L-BFGS-retry1] iter  1500 | loss 3.114e-04
# [window 4] [L-BFGS-retry1] iter  2000 | loss 1.902e-04
# [window 4] loss 1.552e-04 > 1.0e-04 threshold -> retry 2/2
# [window 4] [L-BFGS-retry2] iter   500 | loss 1.051e-04
# [window 4] [L-BFGS-retry2] iter  1000 | loss 7.040e-05
# [window 4] [L-BFGS-retry2] iter  1500 | loss 5.827e-05
# [window 4] [L-BFGS-retry2] iter  2000 | loss 5.138e-05
# [window 5] [Adam]  epoch     0 | loss 4.404e-01
# [window 5] [Adam]  epoch   500 | loss 7.495e+00
# [window 5] [Adam]  epoch  1000 | loss 4.280e+00
# [window 5] [Adam]  epoch  1500 | loss 1.452e+00
# [window 5] [Adam]  epoch  2000 | loss 4.971e+00
# [window 5] [Adam]  epoch  2500 | loss 3.330e+00
# [window 5] [Adam]  epoch  3000 | loss 1.664e+00
# [window 5] [Adam]  epoch  3500 | loss 4.697e+00
# [window 5] [L-BFGS] iter   500 | loss 2.309e-06
# [window 6] [Adam]  epoch     0 | loss 6.512e-05
# [window 6] [Adam]  epoch   500 | loss 1.778e-02
# [window 6] [Adam]  epoch  1000 | loss 4.938e-03
# [window 6] [Adam]  epoch  1500 | loss 3.627e-04
# [window 6] [Adam]  epoch  2000 | loss 1.448e+00
# [window 6] [Adam]  epoch  2500 | loss 3.460e+00
# [window 6] [Adam]  epoch  3000 | loss 9.089e-01
# [window 6] [Adam]  epoch  3500 | loss 1.240e+00
# [window 7] [Adam]  epoch     0 | loss 1.105e-04
# [window 7] [Adam]  epoch   500 | loss 4.025e-01
# [window 7] [Adam]  epoch  1000 | loss 3.747e-01
# [window 7] [Adam]  epoch  1500 | loss 3.528e-01
# [window 7] [Adam]  epoch  2000 | loss 3.143e-01
# [window 7] [Adam]  epoch  2500 | loss 3.241e-01
# [window 7] [Adam]  epoch  3000 | loss 3.330e-01
# [window 7] [Adam]  epoch  3500 | loss 3.312e-01
# [window 8] [Adam]  epoch     0 | loss 2.934e-04
# [window 8] [Adam]  epoch   500 | loss 1.390e-01
# [window 8] [Adam]  epoch  1000 | loss 3.515e+00
# [window 8] [Adam]  epoch  1500 | loss 3.289e+00
# [window 8] [Adam]  epoch  2000 | loss 8.018e-03
# [window 8] [Adam]  epoch  2500 | loss 8.831e-01
# [window 8] [Adam]  epoch  3000 | loss 7.283e+00
# [window 8] [Adam]  epoch  3500 | loss 4.434e+00
# [window 9] [Adam]  epoch     0 | loss 2.897e-04
# [window 9] [Adam]  epoch   500 | loss 3.272e+00
# [window 9] [Adam]  epoch  1000 | loss 6.712e-01
# [window 9] [Adam]  epoch  1500 | loss 1.256e-01
# [window 9] [Adam]  epoch  2000 | loss 5.851e+00
# [window 9] [Adam]  epoch  2500 | loss 2.332e-01
# [window 9] [Adam]  epoch  3000 | loss 1.251e+00
# [window 9] [Adam]  epoch  3500 | loss 3.054e+00
# [window 10] [Adam]  epoch     0 | loss 2.545e-04
# [window 10] [Adam]  epoch   500 | loss 2.499e+00
# [window 10] [Adam]  epoch  1000 | loss 4.775e-01
# [window 10] [Adam]  epoch  1500 | loss 9.673e-02
# [window 10] [Adam]  epoch  2000 | loss 4.103e+00
# [window 10] [Adam]  epoch  2500 | loss 1.028e-01
# [window 10] [Adam]  epoch  3000 | loss 2.436e-01
# [window 10] [Adam]  epoch  3500 | loss 4.078e-01
# [window 10] loss 1.882e-04 > 1.0e-04 threshold -> retry 1/2
# [window 11] [Adam]  epoch     0 | loss 7.956e-04
# [window 11] [Adam]  epoch   500 | loss 5.992e-01
# [window 11] [Adam]  epoch  1000 | loss 1.742e-01
# [window 11] [Adam]  epoch  1500 | loss 8.585e-03
# [window 11] [Adam]  epoch  2000 | loss 1.933e-01
# [window 11] [Adam]  epoch  2500 | loss 8.595e-01
# [window 11] [Adam]  epoch  3000 | loss 3.807e+00
# [window 11] [Adam]  epoch  3500 | loss 2.099e+00
# [window 12] [Adam]  epoch     0 | loss 4.283e-03
# [window 12] [Adam]  epoch   500 | loss 7.968e-01
# [window 12] [Adam]  epoch  1000 | loss 1.911e-03
# [window 12] [Adam]  epoch  1500 | loss 2.089e-01
# [window 12] [Adam]  epoch  2000 | loss 1.324e+00
# [window 12] [Adam]  epoch  2500 | loss 1.123e+00
# [window 12] [Adam]  epoch  3000 | loss 2.990e-01
# [window 12] [Adam]  epoch  3500 | loss 7.766e-02
# [window 13] [Adam]  epoch     0 | loss 1.150e-02
# [window 13] [Adam]  epoch   500 | loss 4.103e-01
# [window 13] [Adam]  epoch  1000 | loss 6.696e-02
# [window 13] [Adam]  epoch  1500 | loss 1.220e-03
# [window 13] [Adam]  epoch  2000 | loss 2.460e-01
# [window 13] [Adam]  epoch  2500 | loss 3.568e-01
# [window 13] [Adam]  epoch  3000 | loss 3.587e-02
# [window 13] [Adam]  epoch  3500 | loss 4.801e-01
# [window 14] [Adam]  epoch     0 | loss 2.191e-04
# [window 14] [Adam]  epoch   500 | loss 1.291e-07
# [window 14] [Adam]  epoch  1000 | loss 1.771e-08
# [window 14] [Adam]  epoch  1500 | loss 7.249e-09
# [window 14] [Adam]  epoch  2000 | loss 9.172e-09
# [window 14] [Adam]  epoch  2500 | loss 2.200e-05
# [window 15] [Adam]  epoch     0 | loss 4.555e-06
# [window 15] [Adam]  epoch   500 | loss 4.726e-08
# [window 15] [Adam]  epoch  1000 | loss 4.738e-08
# [window 15] [Adam]  epoch  1500 | loss 3.041e-08
# [window 15] [Adam]  epoch  2000 | loss 9.530e-09
# [window 15] [Adam]  epoch  2500 | loss 5.761e-09
# [window 16] [Adam]  epoch     0 | loss 1.092e-01
# [window 16] [Adam]  epoch   500 | loss 7.183e-01
# [window 16] [Adam]  epoch  1000 | loss 2.703e+00
# [window 16] [Adam]  epoch  1500 | loss 1.156e-01
# [window 16] [Adam]  epoch  2000 | loss 2.196e-01
# [window 16] [Adam]  epoch  2500 | loss 1.798e-01
# [window 16] [Adam]  epoch  3000 | loss 2.127e-01
# [window 16] [Adam]  epoch  3500 | loss 8.037e-02
# [window 16] [L-BFGS] iter   500 | loss 1.045e-03
# [window 16] [L-BFGS] iter  1000 | loss 4.886e-04
# [window 16] [L-BFGS] iter  1500 | loss 2.471e-04
# [window 16] [L-BFGS] iter  2000 | loss 1.612e-04
# [window 16] [L-BFGS] iter  2500 | loss 1.612e-04
# [window 16] loss 1.612e-04 > 1.0e-04 threshold -> retry 1/2
# [window 16] [L-BFGS-retry1] iter   500 | loss 9.605e-05
# [window 16] [L-BFGS-retry1] iter  1000 | loss 9.604e-05
# [window 16] [L-BFGS-retry1] iter  1500 | loss 9.604e-05
# [window 16] [L-BFGS-retry1] iter  2000 | loss 9.603e-05
# [window 16] [L-BFGS-retry1] iter  2500 | loss 9.603e-05
# [window 17] [Adam]  epoch     0 | loss 1.223e+12
# [window 17] [Adam]  epoch   500 | loss 3.810e+04
# [window 17] [Adam]  epoch  1000 | loss 4.068e+04
# [window 17] [Adam]  epoch  1500 | loss 3.448e+04
# [window 17] [Adam]  epoch  2000 | loss 4.043e+04
# [window 17] [Adam]  epoch  2500 | loss 4.286e+04
# [window 17] [Adam]  epoch  3000 | loss 3.873e+04
# [window 17] [Adam]  epoch  3500 | loss 1.796e+08
# [window 17] [L-BFGS] iter   500 | loss 2.608e+04
# [window 17] [L-BFGS] iter  1000 | loss 1.937e+04
# [window 17] [L-BFGS] iter  1500 | loss 1.355e+04
# [window 17] [L-BFGS] iter  2000 | loss 9.288e+03
# [window 17] loss 8.205e+03 > 1.0e-04 threshold -> retry 1/2
# [window 17] [L-BFGS-retry1] iter   500 | loss 7.167e+03
# [window 17] [L-BFGS-retry1] iter  1000 | loss 6.117e+03
# [window 17] [L-BFGS-retry1] iter  1500 | loss 5.715e+03
# [window 17] [L-BFGS-retry1] iter  2000 | loss 5.552e+03
# [window 17] loss 5.490e+03 > 1.0e-04 threshold -> retry 2/2
# [window 17] [L-BFGS-retry2] iter   500 | loss 7.675e+03
# [window 17] [L-BFGS-retry2] iter  1000 | loss 6.603e+03
# [window 17] [L-BFGS-retry2] iter  1500 | loss 6.403e+03
# [window 17] [L-BFGS-retry2] iter  2000 | loss 6.177e+03
# [window 18] [Adam]  epoch     0 | loss 7.409e+11
# [window 18] [Adam]  epoch   500 | loss 3.453e+06
# [window 18] [Adam]  epoch  1000 | loss 5.077e+03
# [window 18] [Adam]  epoch  1500 | loss 1.598e+02
# [window 18] [Adam]  epoch  2000 | loss 8.171e+01
# [window 18] [Adam]  epoch  2500 | loss 1.581e+01
# [window 18] [Adam]  epoch  3000 | loss 1.451e+01
# [window 18] [Adam]  epoch  3500 | loss 1.757e+01
# [window 18] [L-BFGS] iter   500 | loss 7.599e-04
# [window 18] [L-BFGS] iter  1000 | loss 3.423e-02
# [window 18] [L-BFGS] iter  1500 | loss 4.858e-05
# [window 18] [L-BFGS] iter  2000 | loss 4.855e-05
# [window 18] [L-BFGS] iter  2500 | loss 4.855e-05
# [window 19] [Adam]  epoch     0 | loss 2.419e+01
# [window 19] [Adam]  epoch   500 | loss 1.077e+01
# [window 19] [Adam]  epoch  1000 | loss 3.221e+00
# [window 19] [Adam]  epoch  1500 | loss 9.485e-03
# [window 19] [Adam]  epoch  2000 | loss 9.559e-01
# [window 19] [Adam]  epoch  2500 | loss 1.404e+00
# [window 19] [Adam]  epoch  3000 | loss 4.873e+00
# [window 19] [Adam]  epoch  3500 | loss 1.833e+00
# [window 19] [L-BFGS] iter   500 | loss 4.919e-06
# [window 20] [Adam]  epoch     0 | loss 7.099e-04
# [window 20] [Adam]  epoch   500 | loss 1.222e+00
# [window 20] [Adam]  epoch  1000 | loss 2.567e-01
# [window 20] [Adam]  epoch  1500 | loss 8.562e-02
# [window 20] [Adam]  epoch  2000 | loss 8.259e-02
# [window 20] [Adam]  epoch  2500 | loss 1.773e-01
# [window 20] [Adam]  epoch  3000 | loss 2.821e-01
# [window 20] [Adam]  epoch  3500 | loss 3.992e-01
# [window 20] [L-BFGS] iter   500 | loss 6.489e-06
# [window 21] [Adam]  epoch     0 | loss 1.420e-03
# [window 21] [Adam]  epoch   500 | loss 9.156e-01
# [window 21] [Adam]  epoch  1000 | loss 2.472e-02
# [window 21] [Adam]  epoch  1500 | loss 3.735e-01
# [window 21] [Adam]  epoch  2000 | loss 9.589e-01
# [window 21] [Adam]  epoch  2500 | loss 3.171e-02
# [window 21] [Adam]  epoch  3000 | loss 6.221e-01
# [window 21] [Adam]  epoch  3500 | loss 3.907e-02
# [window 22] [Adam]  epoch     0 | loss 4.073e-03
# [window 22] [Adam]  epoch   500 | loss 5.328e-01
# [window 22] [Adam]  epoch  1000 | loss 1.360e-02
# [window 22] [Adam]  epoch  1500 | loss 2.137e-01
# [window 22] [Adam]  epoch  2000 | loss 8.478e-01
# [window 22] [Adam]  epoch  2500 | loss 8.718e-01
# [window 22] [Adam]  epoch  3000 | loss 1.799e-01
# [window 22] [Adam]  epoch  3500 | loss 3.916e-02
# [window 22] loss 1.038e-04 > 1.0e-04 threshold -> retry 1/2
# [window 22] loss 1.547e-04 > 1.0e-04 threshold -> retry 2/2
# [window 23] [Adam]  epoch     0 | loss 1.881e-02
# [window 23] [Adam]  epoch   500 | loss 1.382e-01
# [window 23] [Adam]  epoch  1000 | loss 3.159e-02
# [window 23] [Adam]  epoch  1500 | loss 1.287e-01
# [window 23] [Adam]  epoch  2000 | loss 3.051e-02
# [window 23] [Adam]  epoch  2500 | loss 1.299e-01
# [window 23] [Adam]  epoch  3000 | loss 3.248e-02
# [window 23] [Adam]  epoch  3500 | loss 1.315e-01
# [window 23] [L-BFGS] iter   500 | loss 2.760e-05
# [window 23] [L-BFGS] iter  1000 | loss 2.760e-05
# [window 23] [L-BFGS] iter  1500 | loss 2.760e-05
# [window 23] [L-BFGS] iter  2000 | loss 2.760e-05
# [window 24] [Adam]  epoch     0 | loss 2.612e-01
# [window 24] [Adam]  epoch   500 | loss 2.327e+00
# [window 24] [Adam]  epoch  1000 | loss 5.167e-01
# [window 24] [Adam]  epoch  1500 | loss 3.929e-01
# [window 24] [Adam]  epoch  2000 | loss 4.983e-01
# [window 24] [Adam]  epoch  2500 | loss 5.883e-01
# [window 24] [Adam]  epoch  3000 | loss 3.982e-01
# [window 24] [Adam]  epoch  3500 | loss 4.730e-01
# [window 24] [L-BFGS] iter   500 | loss 7.687e+00
# [window 24] [L-BFGS] iter  1000 | loss 4.605e-02
# [window 24] [L-BFGS] iter  1500 | loss 4.495e-02
# [window 24] [L-BFGS] iter  2000 | loss 4.300e-02
# [window 24] loss 4.106e-02 > 1.0e-04 threshold -> retry 1/2
# [window 24] [L-BFGS-retry1] iter   500 | loss 3.685e-02
# [window 24] [L-BFGS-retry1] iter  1000 | loss 3.495e-02
# [window 24] [L-BFGS-retry1] iter  1500 | loss 3.357e-02
# [window 24] [L-BFGS-retry1] iter  2000 | loss 3.276e-02
# [window 24] [L-BFGS-retry1] iter  2500 | loss 3.276e-02
# [window 24] loss 3.276e-02 > 1.0e-04 threshold -> retry 2/2
# [window 24] [L-BFGS-retry2] iter   500 | loss 3.089e-02
# [window 24] [L-BFGS-retry2] iter  1000 | loss 3.004e-02
# [window 24] [L-BFGS-retry2] iter  1500 | loss 2.988e-02
# [window 24] [L-BFGS-retry2] iter  2000 | loss 2.988e-02
# [window 24] [L-BFGS-retry2] iter  2500 | loss 2.988e-02
# [window 25] [Adam]  epoch     0 | loss 4.832e+14
# [window 25] [Adam]  epoch   500 | loss 4.590e+08
# [window 25] [Adam]  epoch  1000 | loss 1.879e+08
# [window 25] [Adam]  epoch  1500 | loss 1.599e+08
# [window 25] [Adam]  epoch  2000 | loss 1.170e+08
# [window 25] [Adam]  epoch  2500 | loss 9.182e+07
# [window 25] [Adam]  epoch  3000 | loss 7.561e+07
# [window 25] [Adam]  epoch  3500 | loss 6.265e+07
# [window 25] [L-BFGS] iter   500 | loss 1.866e+06
# [window 25] [L-BFGS] iter  1000 | loss 3.738e+05
# [window 25] [L-BFGS] iter  1500 | loss 3.905e+04
# [window 25] [L-BFGS] iter  2000 | loss 9.735e+03
# [window 25] loss 4.670e+03 > 1.0e-04 threshold -> retry 1/2
# [window 25] [L-BFGS-retry1] iter   500 | loss 2.581e+03
# [window 25] [L-BFGS-retry1] iter  1000 | loss 1.295e+03
# [window 25] [L-BFGS-retry1] iter  1500 | loss 8.661e+02
# [window 25] [L-BFGS-retry1] iter  2000 | loss 6.358e+02
# [window 25] loss 6.113e+02 > 1.0e-04 threshold -> retry 2/2
# [window 25] [L-BFGS-retry2] iter   500 | loss 7.760e+02
# [window 25] [L-BFGS-retry2] iter  1000 | loss 6.577e+02
# [window 25] [L-BFGS-retry2] iter  1500 | loss 5.925e+02
# [window 25] [L-BFGS-retry2] iter  2000 | loss 5.695e+02
# [window 26] [Adam]  epoch     0 | loss 4.336e+14
# [window 26] [Adam]  epoch   500 | loss 1.340e+05
# [window 26] [Adam]  epoch  1000 | loss 6.581e+04
# [window 26] [Adam]  epoch  1500 | loss 8.631e+04
# [window 26] [Adam]  epoch  2000 | loss 6.639e+04
# [window 26] [Adam]  epoch  2500 | loss 4.114e+04
# [window 26] [L-BFGS] iter   500 | loss 1.861e+04
# [window 26] [L-BFGS] iter  1000 | loss 1.636e+04
# [window 26] [L-BFGS] iter  1500 | loss 1.420e+04
# [window 26] [L-BFGS] iter  2000 | loss 1.292e+04
# [window 26] loss 1.277e+04 > 1.0e-04 threshold -> retry 1/2
# [window 26] [L-BFGS-retry1] iter   500 | loss 1.126e+04
# [window 26] [L-BFGS-retry1] iter  1000 | loss 6.300e+03
# [window 26] [L-BFGS-retry1] iter  1500 | loss 5.265e+03
# [window 26] [L-BFGS-retry1] iter  2000 | loss 4.849e+03
# [window 26] loss 4.814e+03 > 1.0e-04 threshold -> retry 2/2
# [window 26] [L-BFGS-retry2] iter   500 | loss 6.674e+03
# [window 26] [L-BFGS-retry2] iter  1000 | loss 6.227e+03
# [window 26] [L-BFGS-retry2] iter  1500 | loss 6.129e+03
# [window 26] [L-BFGS-retry2] iter  2000 | loss 6.007e+03
# [window 27] [Adam]  epoch     0 | loss 3.160e+11
# [window 27] [Adam]  epoch   500 | loss 3.294e+04
# [window 27] [Adam]  epoch  1000 | loss 4.716e+04
# [window 27] [Adam]  epoch  1500 | loss 4.258e+04
# [window 27] [Adam]  epoch  2000 | loss 6.114e+04
# [window 27] [Adam]  epoch  2500 | loss 5.668e+04
# [window 27] [L-BFGS] iter   500 | loss 3.403e+03
# [window 27] [L-BFGS] iter  1000 | loss 2.266e+03
# [window 27] [L-BFGS] iter  1500 | loss 2.046e+03
# [window 27] [L-BFGS] iter  2000 | loss 1.720e+03
# [window 27] loss 9.902e+02 > 1.0e-04 threshold -> retry 1/2
# [window 27] [L-BFGS-retry1] iter   500 | loss 9.255e+02
# [window 27] [L-BFGS-retry1] iter  1000 | loss 8.021e+02
# [window 27] [L-BFGS-retry1] iter  1500 | loss 4.890e+02
# [window 27] [L-BFGS-retry1] iter  2000 | loss 2.884e+02
# [window 27] loss 2.754e+02 > 1.0e-04 threshold -> retry 2/2
# [window 27] [L-BFGS-retry2] iter   500 | loss 4.340e+02
# [window 27] [L-BFGS-retry2] iter  1000 | loss 3.497e+02
# [window 27] [L-BFGS-retry2] iter  1500 | loss 2.448e+02
# [window 27] [L-BFGS-retry2] iter  2000 | loss 2.243e+02
# [window 28] [Adam]  epoch     0 | loss 6.458e+04
# [window 28] [Adam]  epoch   500 | loss 1.186e-02
# [window 28] [Adam]  epoch  1000 | loss 1.018e-02
# [window 28] [Adam]  epoch  1500 | loss 6.456e-03
# [window 28] [Adam]  epoch  2000 | loss 8.194e-03
# [window 28] [Adam]  epoch  2500 | loss 8.731e-03
# [window 29] [Adam]  epoch     0 | loss 1.297e-01
# [window 29] [Adam]  epoch   500 | loss 9.691e+00
# [window 29] [Adam]  epoch  1000 | loss 1.017e-03
# [window 29] [Adam]  epoch  1500 | loss 1.576e-01
# [window 29] [Adam]  epoch  2000 | loss 4.713e-02
# [window 29] [Adam]  epoch  2500 | loss 5.650e+00
# [window 29] [Adam]  epoch  3000 | loss 3.309e+00
# [window 30] [Adam]  epoch     0 | loss 2.141e-05
# [window 30] [Adam]  epoch   500 | loss 9.014e+00
# [window 30] [Adam]  epoch  1000 | loss 2.192e+00
# [window 30] [Adam]  epoch  1500 | loss 2.907e-01
# [window 30] [Adam]  epoch  2000 | loss 1.698e-02
# [window 30] [Adam]  epoch  2500 | loss 2.827e+01
# [window 30] [Adam]  epoch  3000 | loss 6.305e+00
# [window 31] [Adam]  epoch     0 | loss 1.627e-04
# [window 31] [Adam]  epoch   500 | loss 1.550e-01
# [window 31] [Adam]  epoch  1000 | loss 1.058e+00
# [window 31] [Adam]  epoch  1500 | loss 1.157e-01
# [window 31] [Adam]  epoch  2000 | loss 1.192e-02
# [window 31] [Adam]  epoch  2500 | loss 2.578e-01
# [window 31] [Adam]  epoch  3000 | loss 3.336e+00
# [window 32] [Adam]  epoch     0 | loss 1.064e-05
# [window 32] [Adam]  epoch   500 | loss 1.362e+00
# [window 32] [Adam]  epoch  1000 | loss 8.287e+00
# [window 32] [Adam]  epoch  1500 | loss 4.951e-01
# [window 32] [Adam]  epoch  2000 | loss 3.723e-04
# [window 32] [Adam]  epoch  2500 | loss 5.152e-01
# [window 32] [Adam]  epoch  3000 | loss 4.844e-01
# Time-marching training complete in 2453.3s.

# %%
t_eval = np.linspace(0, T_FINAL, 2000)
sol = solve_ivp(van_der_pol_rhs, [0, T_FINAL], [X0, V0], t_eval=t_eval, method="RK45", rtol=1e-10, atol=1e-10)
x_reference = sol.y[0]
v_reference = sol.y[1]

x_pred = np.zeros_like(t_eval)
for w, model_w in enumerate(models):
    t_start = window_edges[w]
    t_end = window_edges[w + 1]
    mask = (t_eval >= t_start) & (t_eval <= t_end + 1e-9)
    if not np.any(mask):
        continue
    t_local = torch.tensor(t_eval[mask].reshape(-1, 1), dtype=torch.get_default_dtype(), device=device)
    with torch.no_grad():
        x_local = model_w(t_local).cpu().numpy().flatten()
    x_pred[mask] = x_local

# %%
mse = np.mean((x_pred - x_reference) ** 2)
relative_l2_error = np.linalg.norm(x_pred - x_reference) / np.linalg.norm(x_reference)
final_training_loss = full_history[-1]
n_params = sum(p.numel() for p in models[0].parameters())

# Calculate additional metrics
mae = np.mean(np.abs(x_pred - x_reference))
max_error = np.max(np.abs(x_pred - x_reference))
rmse = np.sqrt(mse)

t_res_test = torch.tensor(
    np.random.uniform(0.0, T_FINAL, size=(2000, 1)),
    dtype=torch.get_default_dtype(), device=device,
)
residual_vals = []
for w, model_w in enumerate(models):
    t_start = window_edges[w]
    t_end = window_edges[w + 1]
    mask = (t_res_test.detach().cpu().numpy().flatten() >= t_start) & \
           (t_res_test.detach().cpu().numpy().flatten() <= t_end)
    if np.any(mask):
        t_sub = t_res_test[mask].clone().detach().requires_grad_(True)
        f_sub = physics_residual(model_w, t_sub)
        residual_vals.append(f_sub.detach().cpu().numpy())
mean_physics_residual = np.mean(np.concatenate(residual_vals) ** 2) if residual_vals else float("nan")

print(f"Selected sigma: {FOURIER_SIGMA}")
print(f"Selected mapping_size: {FOURIER_MAPPING_SIZE}")
print(f"MSE: {mse:.3e}")
print(f"RMSE: {rmse:.3e}")
print(f"Relative L2 error: {relative_l2_error:.3e}")
print(f"MAE: {mae:.3e}")
print(f"Max Error: {max_error:.3e}")
print(f"Final training loss: {final_training_loss:.3e}")
print(f"Mean physics residual (test points): {mean_physics_residual:.3e}")
print(f"Training time: {training_time:.1f}s")
print(f"Trainable parameters (per window model): {n_params}")
print(f"Windows: {n_windows_actual}")
# Out:
# Selected sigma: 0.5
# Selected mapping_size: 32
# MSE: 9.892e+00
# RMSE: 3.145e+00
# Relative L2 error: 1.860e+00
# MAE: 2.972e+00
# Max Error: 4.011e+00
# Final training loss: 2.028e-06
# Mean physics residual (test points): 3.110e+02
# Training time: 2453.3s
# Trainable parameters (per window model): 5281
# Windows: 33

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 9))

axes[0, 0].plot(t_eval, x_reference, "b-", linewidth=2, label="Reference (RK45)")
axes[0, 0].plot(t_eval, x_pred, "r--", linewidth=2, label="Fourier Feature PINN (time-marched)")
for edge in window_edges[1:-1]:
    axes[0, 0].axvline(edge, color="gray", linestyle=":", linewidth=0.7)
axes[0, 0].set_xlabel("t")
axes[0, 0].set_ylabel("x(t)")
axes[0, 0].set_title("Van der Pol oscillator: Fourier Feature PINN vs. reference (non-uniform windows)")
axes[0, 0].legend()

axes[0, 1].semilogy(full_history, label="physics residual loss")
axes[0, 1].set_xlabel("iteration (concatenated across windows)")
axes[0, 1].set_ylabel("loss (log scale)")
axes[0, 1].set_title("Training loss history")
axes[0, 1].legend()

axes[1, 0].plot(t_eval, np.abs(x_pred - x_reference), "k-")
for edge in window_edges[1:-1]:
    axes[1, 0].axvline(edge, color="gray", linestyle=":", linewidth=0.7)
axes[1, 0].set_xlabel("t")
axes[1, 0].set_ylabel("|x_pred - x_reference|")
axes[1, 0].set_title("Absolute error")

x_pred_dot = np.gradient(x_pred, t_eval)
axes[1, 1].plot(x_reference, v_reference, "b-", linewidth=2, label="Reference")
axes[1, 1].plot(x_pred, x_pred_dot, "r--", linewidth=2, label="Fourier Feature PINN")
axes[1, 1].set_xlabel("x")
axes[1, 1].set_ylabel("x'")
axes[1, 1].set_title("Phase portrait")
axes[1, 1].legend()

plt.tight_layout()
plt.savefig("fourier_pinn_adaptive_results.png", dpi=150)
plt.show()

# %%
fig2, ax2 = plt.subplots(figsize=(9, 3.5))
ax2.plot(coarse_t, coarse_monitor, "b-", linewidth=1.2, label="monitor (weighted |v| + |accel|)")
for edge in window_edges:
    ax2.axvline(edge, color="gray", linestyle=":", linewidth=0.7)
ax2.set_xlabel("t")
ax2.set_ylabel("monitor value")
ax2.set_title("Window placement: dense near fast transitions, sparse in slow regions")
ax2.legend()
plt.tight_layout()
plt.savefig("fourier_window_placement_diagnostic.png", dpi=150)
plt.show()
